# %%
import pandas as pd

# %%
mydf=pd.read_csv("/content/mydf.csv")
mydf

# %%
# Seaborn is another which is dedicated for visualization
import seaborn as sns

# %%
pl=sns.lineplot(y="Names",x="SEM1",data=mydf)

# %%
sns.relplot(data=mydf,y="Names",x="SEM1",col="Placed")
#col==> Graphes are seperated based on this column

# %%
mydf1=pd.read_excel("/content/diabetes.xlsx")
mydf1.tail()

# %%
mydf1["Index"]=range(1,769)
mydf1

# %%
#Plot a relational plot using age->>Y-axis and index-->X-axis and sperated as bi-class
sns.relplot(data=mydf1,x="Index",y="age",col="class")

# %%
mydf3=sns.load_dataset("tips")
mydf3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="sex")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker",style="time",palette="dark")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker",style="time",palette="pastel")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker",style="time",palette="deep")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker",style="time",palette="colorblind")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker",style="time",palette="muted")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="smoker",style="time",palette="bright")

# %%
sns.relplot(data=mydf3,x="total_bill",y="day")

# %%
sns.catplot(data=mydf3,x="total_bill",y="day")

# %%
sns.relplot(data=mydf3,x="total_bill",y="tip",hue="size",palette="dark")

# %%
mydf4=sns.load_dataset("dowjones")
mydf4
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot(data=mydf4,x="Date",y="Price",kind="line")

# %%
mydf5=sns.load_dataset("fmri")
mydf5
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=mydf5,x="timepoint",y="signal",hue="event",style="region",palette="pastel")

# %%
sns.relplot(data=mydf5,x="timepoint",y="signal")

# %%
sns.catplot(data=mydf5,x="timepoint",y="signal")
#category plot based on y

# %%
sns.catplot(data=mydf3,x="total_bill",y="time",kind="violin",hue="smoker")

# %%
sns.catplot(data=mydf3,x="total_bill",y="time",kind="box",hue="smoker")

# %%
sns.catplot(data=mydf3,x="total_bill",y="time",kind="bar",hue="smoker")
#strip', 'swarm', 'box', 'boxen', 'violin', 'bar', 'count', and 'point' are kinds
